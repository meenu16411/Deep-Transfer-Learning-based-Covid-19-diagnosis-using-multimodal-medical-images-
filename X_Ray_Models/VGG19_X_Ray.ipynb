# %%
# Mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importing all requirements
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

from glob import glob
import pandas as pd
import cv2

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
#define size to which images are to be resized
IMAGE_SIZE = [224, 224]

# training config:
epochs = 60
batch_size = 32

#define paths
covid_path =  r'/content/drive/MyDrive/X-ray/train/COVID'
noncovid_path =  r'/content/drive/MyDrive/X-ray/train/Non-COVID'
# Use glob to grab images from path .jpg or jpeg
covid_files_pr  = glob(covid_path + '/*')
noncovid_files_pre = glob(noncovid_path + '/*')
#print(covid_files)
covid_files=covid_files_pr[0:2500]
print(covid_files)
noncovid_files =noncovid_files_pre[0:2500]
# Out:
# ['/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (627).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person410_virus_821.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person20_virus_51.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person1156_virus_1936.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/aug_covid-19-pneumonia-19_avg_0.jpg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (600).jpg', '/content/drive/MyDrive/X-ray/train/COVID/aug_41591_2020_819_Fig1_HTML.webp-day10_sharp_4.jpg', '/content/drive/MyDrive/X-ray/train/COVID/person1145_virus_1902.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/7EF28E12-F628-4BEC-A8C5-E6277C2E4F60.png', '/content/drive/MyDrive/X-ray/train/COVID/441c9cdd.png', '/content/drive/MyDrive/X-ray/train/COVID/person832_virus_1468.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person113_virus_216.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/covid-19-pneumonia-58-prior.jpg', '/content/drive/MyDrive/X-ray/train/COVID/person1600_virus_2777.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/IM-0115-0001.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person1161_virus_1948.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/aug_ryct.2020200034.fig5-day4._PL_1.jpg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (629).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person131_virus_265.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (7).png', '/content/drive/MyDrive/X-ray/train/COVID/person335_virus_690.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (579).jpg', '/content/drive/MyDrive/X-ray/train/COVID/86d19bba.png', '/content/drive/MyDrive/X-ray/train/COVID/person1556_virus_2699.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (439).jpg', '/content/drive/MyDrive/X-ray/train/COVID/0101.png', '/content/drive/MyDrive/X-ray/train/COVID/radiol.2020200490.fig3.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person1571_virus_2728.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person724_virus_1344.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person407_virus_811.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (375).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person997_virus_1678.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person358_virus_737.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (54).png', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (313).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person1082_virus_1794.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person1274_virus_2193.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person96_virus_178.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/7afaaccc.jpg', '/content/drive/MyDrive/X-ray/train/COVID/aug_kjr-21-e24-g002-l-a_sharp_1.jpg', '/content/drive/MyDrive/X-ray/train/COVID/aug_ryct.2020200034.fig5-day7._PL_4.jpg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (51).png', '/content/drive/MyDrive/X-ray/train/COVID/aug_ryct.2020200028.fig1a._avg_0.jpg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (592).jpg', '/content/drive/MyDrive/X-ray/train/COVID/aug_covid-19-pneumonia-7-PA_avg_0.jpg', '/content/drive/MyDrive/X-ray/train/COVID/person125_virus_254.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/aug_figure1-5e75d0940b71e1b702629659-98-right._sharp_4.jpg', '/content/drive/MyDrive/X-ray/train/COVID/person1328_virus_2294.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/aa9655de.png', '/content/drive/MyDrive/X-ray/train/COVID/aug_41591_2020_819_Fig1_HTML.webp-day10_PL_0.jpg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (311).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person1668_virus_2882.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (137).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person401_virus_795.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (83).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person1537_virus_2674.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (124).png', '/content/drive/MyDriv ...

# %%
# Visualize file variable contents
print("First 5 Covid Files: ",covid_files[0:5])
print("Total Count: ",len(covid_files))
print("First 5 NonCovid Files: ",noncovid_files[0:5])
print("Total Count: ",len(noncovid_files))
# Out:
# First 5 Covid Files:  ['/content/drive/MyDrive/X-ray/train/COVID/COVID-19 (627).jpg', '/content/drive/MyDrive/X-ray/train/COVID/person410_virus_821.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person20_virus_51.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/person1156_virus_1936.jpeg', '/content/drive/MyDrive/X-ray/train/COVID/aug_covid-19-pneumonia-19_avg_0.jpg']
# Total Count:  2500
# First 5 NonCovid Files:  ['/content/drive/MyDrive/X-ray/train/Non-COVID/Non-COVID-19 (741).jpeg', '/content/drive/MyDrive/X-ray/train/Non-COVID/NORMAL2-IM-1273-0001.jpeg', '/content/drive/MyDrive/X-ray/train/Non-COVID/Non-COVID-19 (525).jpeg', '/content/drive/MyDrive/X-ray/train/Non-COVID/00002229_003.png', '/content/drive/MyDrive/X-ray/train/Non-COVID/NORMAL (757).png']
# Total Count:  2500

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('Xray_COVID') #append class label
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('Xray_NonCOVID')

# %%
# look at a random image for fun
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 CT Scan')
plot_images(noncovid_images, 'Negative COVID-19 CT Scan')

# %%
# Convert to array and Normalize to interval of [0,1]
covid_images = np.array(covid_images) / 255
noncovid_images = np.array(noncovid_images) / 255

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.4)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.4)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
plot_images(covid_x_train, 'X_train')
plot_images(covid_x_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %%
# Building Model
vggModel = VGG19(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = vggModel.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=vggModel.input, outputs=outputs)

for layer in vggModel.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy',
        optimizer='adam',
        metrics=['accuracy']
)

train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
# Visualize Model
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 50178
# =================================================================
# Total params: 20,074,562
# Trainable params: 50,178
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Augment training data
train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
# Fit the Model
history = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/60
# 93/93 [==============================] - 187s 2s/step - loss: 0.7496 - accuracy: 0.7137 - val_loss: 0.4521 - val_accuracy: 0.8040
# Epoch 2/60
# 93/93 [==============================] - 187s 2s/step - loss: 0.4949 - accuracy: 0.7823 - val_loss: 0.4023 - val_accuracy: 0.8285
# Epoch 3/60
# 93/93 [==============================] - 187s 2s/step - loss: 0.4971 - accuracy: 0.7823 - val_loss: 0.3914 - val_accuracy: 0.8380
# Epoch 4/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4602 - accuracy: 0.8053 - val_loss: 0.4516 - val_accuracy: 0.8140
# Epoch 5/60
# 93/93 [==============================] - 187s 2s/step - loss: 0.4485 - accuracy: 0.8130 - val_loss: 0.4119 - val_accuracy: 0.8350
# Epoch 6/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.5203 - accuracy: 0.7937 - val_loss: 0.3576 - val_accuracy: 0.8555
# Epoch 7/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4491 - accuracy: 0.8153 - val_loss: 0.4582 - val_accuracy: 0.8265
# Epoch 8/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4499 - accuracy: 0.8290 - val_loss: 0.3569 - val_accuracy: 0.8540
# Epoch 9/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4318 - accuracy: 0.8293 - val_loss: 0.4079 - val_accuracy: 0.8425
# Epoch 10/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4297 - accuracy: 0.8283 - val_loss: 0.3367 - val_accuracy: 0.8730
# Epoch 11/60
# 93/93 [==============================] - 187s 2s/step - loss: 0.4247 - accuracy: 0.8317 - val_loss: 0.3337 - val_accuracy: 0.8715
# Epoch 12/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4732 - accuracy: 0.8230 - val_loss: 0.4644 - val_accuracy: 0.8295
# Epoch 13/60
# 93/93 [==============================] - 187s 2s/step - loss: 0.4285 - accuracy: 0.8387 - val_loss: 0.3204 - val_accuracy: 0.8700
# Epoch 14/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4239 - accuracy: 0.8307 - val_loss: 0.4202 - val_accuracy: 0.8400
# Epoch 15/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4462 - accuracy: 0.8297 - val_loss: 0.3734 - val_accuracy: 0.8585
# Epoch 16/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4166 - accuracy: 0.8460 - val_loss: 0.3298 - val_accuracy: 0.8650
# Epoch 17/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4669 - accuracy: 0.8163 - val_loss: 0.4250 - val_accuracy: 0.8430
# Epoch 18/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4520 - accuracy: 0.8297 - val_loss: 0.3198 - val_accuracy: 0.8785
# Epoch 19/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4662 - accuracy: 0.8407 - val_loss: 0.3622 - val_accuracy: 0.8660
# Epoch 20/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4530 - accuracy: 0.8333 - val_loss: 0.3268 - val_accuracy: 0.8695
# Epoch 21/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4452 - accuracy: 0.8340 - val_loss: 0.3108 - val_accuracy: 0.8735
# Epoch 22/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4092 - accuracy: 0.8407 - val_loss: 0.3386 - val_accuracy: 0.8685
# Epoch 23/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4693 - accuracy: 0.8290 - val_loss: 0.4475 - val_accuracy: 0.8405
# Epoch 24/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4499 - accuracy: 0.8400 - val_loss: 0.3692 - val_accuracy: 0.8610
# Epoch 25/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4659 - accuracy: 0.8300 - val_loss: 0.3231 - val_accuracy: 0.8685
# Epoch 26/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4939 - accuracy: 0.8293 - val_loss: 0.2961 - val_accuracy: 0.8815
# Epoch 27/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4852 - accuracy: 0.8270 - val_loss: 0.3171 - val_accuracy: 0.8800
# Epoch 28/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4696 - accuracy: 0.8257 - val_loss: 0.2885 - val_accuracy: 0.8875
# Epoch 29/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4723 - accuracy: 0.8377 - val_loss: 0.3084 - val_accuracy: 0.8840
# Epoch 30/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4430 - accuracy: 0.8410 - val_loss: 0.3387 - val_accuracy: 0.8665
# Epoch 31/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4347 - accuracy: 0.8440 - val_loss: 0.2999 - val_accuracy: 0.8860
# Epoch 32/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4509 - accuracy: 0.8453 - val_loss: 0.2857 - val_accuracy: 0.8915
# Epoch 33/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4675 - accuracy: 0.8297 - val_loss: 0.3540 - val_accuracy: 0.8755
# Epoch 34/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4609 - accuracy: 0.8447 - val_loss: 0.4973 - val_accuracy: 0.8430
# Epoch 35/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.5088 - accuracy: 0.8303 - val_loss: 0.3663 - val_accuracy: 0.8675
# Epoch 36/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.5088 - accuracy: 0.8367 - val_loss: 0.4418 - val_accuracy: 0.8435
# Epoch 37/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4404 - accuracy: 0.8420 - val_loss: 0.3701 - val_accuracy: 0.8660
# Epoch 38/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4935 - accuracy: 0.8350 - val_loss: 0.3574 - val_accuracy: 0.8750
# Epoch 39/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4378 - accuracy: 0.8407 - val_loss: 0.3469 - val_accuracy: 0.8770
# Epoch 40/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4509 - accuracy: 0.8417 - val_loss: 0.3124 - val_accuracy: 0.8890
# Epoch 41/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4875 - accuracy: 0.8303 - val_loss: 0.3551 - val_accuracy: 0.8755
# Epoch 42/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4115 - accuracy: 0.8493 - val_loss: 0.3208 - val_accuracy: 0.8870
# Epoch 43/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4456 - accuracy: 0.8410 - val_loss: 0.3392 - val_accuracy: 0.8770
# Epoch 44/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4631 - accuracy: 0.8443 - val_loss: 0.3103 - val_accuracy: 0.8895
# Epoch 45/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4574 - accuracy: 0.8463 - val_loss: 0.3270 - val_accuracy: 0.8820
# Epoch 46/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4453 - accuracy: 0.8383 - val_loss: 0.3036 - val_accuracy: 0.8805
# Epoch 47/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4713 - accuracy: 0.8340 - val_loss: 0.2862 - val_accuracy: 0.8935
# Epoch 48/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4577 - accuracy: 0.8510 - val_loss: 0.3408 - val_accuracy: 0.8785
# Epoch 49/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4459 - accuracy: 0.8473 - val_loss: 0.3275 - val_accuracy: 0.8775
# Epoch 50/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4512 - accuracy: 0.8463 - val_loss: 0.3037 - val_accuracy: 0.8790
# Epoch 51/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4640 - accuracy: 0.8347 - val_loss: 0.4072 - val_accuracy: 0.8615
# Epoch 52/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.5502 - accuracy: 0.8240 - val_loss: 0.3385 - val_accuracy: 0.8785
# Epoch 53/60
# 93/93 [==============================] - 184s 2s/step - loss: 0.4330 - accuracy: 0.8470 - val_loss: 0.3606 - val_accuracy: 0.8815
# Epoch 54/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4769 - accuracy: 0.8453 - val_loss: 0.3534 - val_accuracy: 0.8800
# Epoch 55/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4361 - accuracy: 0.8467 - val_loss: 0.3999 - val_accuracy: 0.8620
# Epoch 56/60
# 93/93 [==============================] - 183s 2s/step - loss: 0.4858 - accuracy: 0.8417 - val_loss: 0.5111 - val_accuracy: 0.8405
# Epoch 57/60
# 93/93 [==============================] - 186s 2s/step - loss: 0.4828 - accuracy: 0.8417 - val_loss: 0.3274 - val_accuracy: 0.8875
# Epoch 58/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4556 - accuracy: 0.8443 - val_loss: 0.3312 - val_accuracy: 0.8835
# Epoch 59/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4602 - accuracy: 0.8340 - val_loss: 0.4074 - val_accuracy: 0.8670
# Epoch 60/60
# 93/93 [==============================] - 185s 2s/step - loss: 0.4731 - accuracy: 0.8453 - val_loss: 0.3070 - val_accuracy: 0.8875

# %%
# Save Model and Weights
model.save('vgg_Xray1.h5')
model.save_weights('vgg_weights_Xray1.hdf5')

# %%
# Load saved model
model = load_model('vgg_Xray1.h5')

# %%
# Predicting using trained model
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
# Printing performance metrics
# ROC
from sklearn import metrics
from sklearn.metrics import roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test_bin, y_pred_bin)
auc=metrics.auc(fpr,tpr)
print("Auc= {:.2f}".format(auc*100))

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for our model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.grid(True)
# Out:
# Auc= 88.75

# %%
# Confusion Matrix
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)

print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization
# Confusion Matrix with Normalized Values

# %%
# Classification Report
from sklearn.metrics import classification_report
print(classification_report(y_test_bin, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      1000
#            1       0.91      0.86      0.88      1000
#
#     accuracy                           0.89      2000
#    macro avg       0.89      0.89      0.89      2000
# weighted avg       0.89      0.89      0.89      2000

# %%
# Accuracy plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('vgg_ct_accuracy.png')
plt.show()
